# %%
# !pip install Keras-Preprocessing
# Out:
# Requirement already satisfied: Keras-Preprocessing in c:\users\ananya\documents\anaconda\lib\site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\ananya\documents\anaconda\lib\site-packages (from Keras-Preprocessing) (1.26.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\ananya\documents\anaconda\lib\site-packages (from Keras-Preprocessing) (1.16.0)

# %%
import numpy as np
import tensorflow as tf
import keras.preprocessing.image
import matplotlib.pyplot as plt

# %%
model =tf.keras.models.load_model('trained_model.keras')

# %%
model.summary
# Out:
# <bound method Model.summary of <Sequential name=sequential, built=True>>

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ananya\documents\anaconda\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ananya\documents\anaconda\lib\site-packages (from opencv-python) (1.26.4)

# %%
import cv2 
image_path= "test/_BrownSpot/shape 171 .jpg"
img=cv2.imread(image_path)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title("test image")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image=tf.keras.preprocessing.image.load_img(image_path,target_size=(128,128))
input_arr=tf.keras.preprocessing.image.img_to_array(image)
input_arr=np.array([input_arr])
print(input_arr.shape)
# Out:
# (1, 128, 128, 3)

# %%
prediction = model.predict(input_arr)
prediction,prediction.shape
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step
# (array([[1.9195782e-06, 9.9834323e-01, 8.0833753e-04, 5.2197615e-06,
#          8.2416186e-04, 3.9263477e-07, 1.6740471e-05]], dtype=float32),
#  (1, 7))

# %%
result_index=np.argmax(prediction)
result_index
# Out:
# 1

# %%
class_name=['Healthy rice',
 '_BrownSpot',
 '_Healthy rice',
 '_Hispa',
 '_LeafBlast',
 'septoria',
 'stripe_rust']

# %%
model_prediction=class_name[result_index]
plt.imshow(img)
plt.title(f"category of leaf:{model_prediction}")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
model_prediction
# Out:
# '_BrownSpot'
